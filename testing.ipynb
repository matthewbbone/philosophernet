# %%
import requests
from bs4 import BeautifulSoup
import lxml
import pickle
import csv
import re
import datetime
import dateutil
import time

# %run -i philnetfuncs.py

# %%
def table_scrape(prefix, ref, vars):

    page = requests.get(prefix + ref)
    soup = BeautifulSoup(page.content, "lxml")

    table = soup.find("table", class_ = "infobox vcard")
    if invalid_table(table):
        table = soup.find("table", class_ = "infobox biography vcard")
    if invalid_table(table):
        table = soup.find("tbody")
        
    rows = table.find_all("tr")

    row_dict = {}
    for r in rows:
        th = r.find("th")
        td = r.find("td")
        if not th is None and not td is None and th.text in vars:
            if th.text in ["Born","Died"]: row_dict[th.text] = date_clean(td.text)
            elif th.text == "School": row_dict[th.text] = school_clean(td)
    
    var_list = []
    for var in vars:
        if var in row_dict:
            var_list.append([var,row_dict[var]])
        else: var_list.append([var,None])
        
    return var_list

def school_clean(td):

    schools = td.find_all('a')
    schools = [s.get_text() for s in schools]
    schools = [re.sub('\[.*\]', '', s) for s in schools]
    schools = [s for s in schools if s != '']

    return schools

# %%
prefix = "https://en.wikipedia.org"
descartes = "/wiki/William_of_Ockham"
vars = ["Born","Died","School"]
table_scrape(prefix, descartes, vars)
# Out:
# [['Born', datetime.date(1285, 1, 1)],
#  ['Died', datetime.date(1347, 1, 1)],
#  ['School',
#   ['Scholasticism', 'Occamism', 'Nominalism', 'Theological voluntarism']]]

# %%
f = open(r'philosophers5.pkl', 'rb')
phil_5 = pickle.load(f)
f.close()

# %%
phil_5 = add_info(prefix, phil_5, vars)

# %%
phil = list(phil_5.values())
[x[5] for x in phil]
# Out:
# [['Rationalism',
#   'Cartesianism',
#   'Mechanism',
#   'Innatism',
#   'Foundationalism',
#   'Conceptualism',
#   'Augustinianism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Corpuscularianism',
#   'Theological voluntarism'],
#  ['Platonism'],
#  ['Peripatetic school', 'Aristotelianism', 'Classical republicanism'],
#  None,
#  ['Aristotelianism'],
#  ['Scholasticism', 'Neoplatonism', 'Augustinianism'],
#  ['Augustinianism'],
#  ['Scholasticism',
#   'Thomism',
#   'Aristotelianism',
#   'Theological intellectualism',
#   'Philosophical realism',
#   'Moderate realism',
#   'Direct realism',
#   'Virtue ethics',
#   'Natural law',
#   'Correspondence theory of truth'],
#  ['Scholasticism', 'Occamism', 'Nominalism', 'Theological voluntarism'],
#  ['Scholasticism', 'Medieval realism', 'School of Salamanca'],
#  ['Pyrrhonism', 'Empiric school'],
#  ['Renaissance humanism', 'Renaissance skepticism', 'Pyrrhonism'],
#  None,
#  None,
#  ['Rationalism',
#   'Spinozism',
#   'Cartesianism',
#   'Foundationalism',
#   'Hegel',
#   'Conceptualism',
#   'Direct realism',
#   'Correspondence theory of truth'],
#  ['Rationalism',
#   'Pluralistic idealism',
#   'Foundationalism',
#   'Conceptualism',
#   'Optimism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Relationism'],
#  ['Empiricism',
#   'Foundationalism',
#   'Conceptualism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Ideational theory of meaning',
#   'Corpuscularianism',
#   'Social contract',
#   'Natural law',
#   'Classical liberalism'],
#  ['Rationalism', 'Cartesianism', 'Augustinianism', 'Occasionalism'],
#  ['Rationalism', 'Augustinianism', 'Jansenism', 'Cartesianism'],
#  ['Cartesianism', 'Jansenism', 'Fideism'],
#  ['Kantianism',
#   'Enlightenment philosophy',
#   'German idealism',
#   'Foundationalism',
#   'Metaphysical conceptualism',
#   'Perceptual non-conceptualism',
#   'Transcendental idealism',
#   'Empirical realism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Liberal naturalism',
#   'Kantian ethics',
#   'Classical liberalism'],
#  ['Continental philosophy',
#   'Phenomenology',
#   'Transcendental constitutive phenomenology',
#   'Genetic phenomenology',
#   'Logical objectivism',
#   'Austrian realism',
#   'early',
#   'Foundationalism',
#   'Conceptualism',
#   'Indirect realism',
#   'Correspondence theory of truth'],
#  ['Classical Greek philosophy'],
#  ['Pythagoreanism'],
#  ['Eleatic school'],
#  ['Ionian'],
#  ['Platonism'],
#  ['Platonism'],
#  ['Middle Platonism'],
#  ['Neoplatonism'],
#  ['Neoplatonism'],
#  ['Neoplatonism'],
#  ['Pluralist school'],
#  ['Aristotelianism'],
#  ['Islamic mathematics', 'Persian poetry', 'Persian philosophy'],
#  None,
#  ['Scholasticism'],
#  ['Aristotelianism', 'Neoplatonism', 'idealism'],
#  ['Aristotelianism'],
#  ['Scholasticism',
#   'Augustinianism',
#   'Neoplatonism',
#   'Philosophical realism',
#   'Medieval realism',
#   'moderate realism'],
#  None,
#  ['Scholasticism'],
#  ['Academic skepticism', 'Classical republicanism'],
#  ['Neoplatonism', 'Christian philosophy'],
#  ['Scholasticism', 'Aristotelianism', 'Medieval realism'],
#  ['Scholasticism', 'Peripatetic', 'Conceptualism'],
#  ['Scholasticism'],
#  ['Scholasticism', 'Nominalism', 'Aristotelianism'],
#  ['Scholasticism', 'Augustinianism'],
#  None,
#  ['British empiricism',
#   'Classical realism',
#   'Corpuscularianism',
#   'Descriptive egoism',
#   'Determinism',
#   'Materialism',
#   'Natural law',
#   'Nominalism',
#   'Social contract'],
#  ['Analytic philosophy',
#   'Aristotelianism',
#   'Empiricism',
#   'Linguistic turn',
#   'Logical atomism',
#   'Foundationalism',
#   'Logicism',
#   'Predicativism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Utilitarianism'],
#  ['Age of Enlightenment', 'Rationalism'],
#  ['Natural law'],
#  ['Continental philosophy',
#   'Phenomenology',
#   'Hermeneutics',
#   'Ontological hermeneutics',
#   'Hermeneutic phenomenology',
#   'early',
#   'Transcendental hermeneutic phenomenology',
#   'late',
#   'Existentialism',
#   'Existential phenomenology',
#   'Irrationalism',
#   'citation needed'],
#  ['Pythagoreanism', 'Neoplatonism', 'Thomism', 'Scotism', 'Mutualism'],
#  ['Continental philosophy', 'Madrid School'],
#  ['Skepticism', 'Pyrrhonism'],
#  ['Pyrrhonism'],
#  ['Pyrrhonism'],
#  ['Pyrrhonism'],
#  ['Scottish Enlightenment',
#   'Naturalism',
#   'Scepticism',
#   'Empiricism',
#   'Irreligion',
#   'Foundationalism',
#   'Newtonianism',
#   'Conceptualism',
#   'Indirect realism',
#   'Correspondence theory of truth',
#   'Moral sentimentalism',
#   'Conservatism'],
#  ['Continental philosophy',
#   'German idealism',
#   'Objective idealism',
#   'Absolute idealism',
#   'Hegelianism',
#   'Historicism',
#   'Naturphilosophie',
#   'Epistemic coherentism',
#   'Conceptualism',
#   'Empirical realism',
#   'Coherence theory of truth'],
#  ['Continental philosophy',
#   'Anti-foundationalism',
#   'Atheism',
#   'Dionysian pessimism',
#   'Existentialism',
#   'Metaphysical voluntarism',
#   'Moral anti-realism',
#   'Nihilism',
#   'Perspectival',
#   'realism',
#   'Perspectivism'],
#  ['Stoicism'],
#  ['Epicureanism', 'Atomism', 'Materialism'],
#  ['Continental philosophy', 'Marxism'],
#  ['Continental philosophy', 'Phenomenology', 'Post-Marxism', 'Postmodernism'],
#  ['Transcendentalism'],
#  ['Lumières', 'Philosophes', 'Deism', 'Classical liberalism'],
#  ['Social contract', 'Romanticism'],
#  ['Continental philosophy',
#   'existentialism',
#   'phenomenology',
#   'existential phenomenology',
#   'hermeneutics',
#   'Western Marxism',
#   'anarchism'],
#  ['Continental philosophy', 'Post-structuralism'],
#  ['Analytic'],
#  ['Continental philosophy',
#   'Existential phenomenology',
#   'Philosophy of life',
#   'incomplete short citation',
#   'Classical republicanism'],
#  ['Continental philosophy',
#   'French Nietzscheanism',
#   'Materialism',
#   'Neo-Spinozism',
#   'Post-structuralism',
#   'Empiricism'],
#  ['Pragmatism', 'Pragmaticism'],
#  ['Pre-Socratic philosophy', 'Atomism', 'Materialism'],
#  ['Epicureanism'],
#  ['Classical realism', 'Classical republicanism'],
#  ['Renaissance humanism', 'Neopythagoreanism'],
#  None,
#  ['Continental philosophy',
#   'Post-Kantian philosophy',
#   'Transcendental idealism',
#   'Metaphysical voluntarism',
#   'Philosophical pessimism'],
#  ['Continental philosophy',
#   'German idealism',
#   'Post-Kantian',
#   'transcendental idealism',
#   'Objective idealism',
#   'Absolute idealism',
#   'Naturphilosophie',
#   'transcendental realism',
#   'transcendental naturalism',
#   'Jena Romanticism',
#   'Romanticism in science',
#   'Correspondence theory of truth'],
#  ['Spinozism', 'Materialism', 'Cartesianism', 'Rationalism'],
#  ['Analytic', 'Neopragmatism'],
#  ['Continental philosophy',
#   'German idealism',
#   'Post-Kantian',
#   'transcendental idealism',
#   'Empirical realism',
#   'Foundationalism',
#   'Coherence theory of truth',
#   'Jena Romanticism',
#   'Romantic nationalism'],
#  ['Enlightenment',
#   'Counter-Enlightenment',
#   'Romantic nationalism',
#   'Anticolonialist',
#   'cosmopolitanism',
#   'Sturm und Drang',
#   'Weimar Classicism',
#   'Historicism',
#   'Romantic hermeneutics',
#   'Classical liberalism'],
#  ['Critical philosophy'],
#  ['Analytic philosophy',
#   'Linguistic turn',
#   'Logical atomism',
#   'Logical behaviorism',
#   'Correspondence theory of truth'],
#  ['Continental philosophy', 'Positivism', 'Existentialism'],
#  ['Western Marxism', 'Structural Marxism', 'Neo-Spinozism'],
#  ['Continental philosophy', 'Post-Marxism'],
#  ['Marxism'],
#  ['Continental philosophy', 'Autonomist Marxism', 'Neo-Spinozism'],
#  ['Pragmatism', 'naturalism'],
#  ['Continental philosophy',
#   'Neo-Kantianism',
#   'Modern Platonism',
#   'Straussian hermeneutics',
#   'Classical republicanism',
#   'Modern republicanism'],
#  ['Continental philosophy', 'Marxist humanism'],
#  None,
#  ['Confucianism'],
#  ['Subjective idealism',
#   'phenomenalism',
#   'Empiricism',
#   'Foundationalism',
#   'Conceptualism',
#   'Indirect realism'],
#  ['Rationalism'],
#  ['algebraic logic'],
#  ['Analytic philosophy',
#   'Linguistic turn',
#   'Logical objectivism',
#   'Modern Platonism',
#   'Logicism',
#   'Transcendental idealism',
#   'Metaphysical realism',
#   'Foundationalism',
#   'Indirect realism',
#   'Redundancy theory of truth'],
#  ['Analytic',
#   'Process philosophy',
#   'Methodological pragmatism',
#   'Pragmatic idealism',
#   'Epistemic coherentism',
#   'Coherence theory of truth'],
#  ['Empiricism'],
#  None,
#  ['Natural law'],
#  ['Cambridge Platonists'],
#  ['Cambridge Platonism'],
#  ['Historicism', 'Christian humanism'],
#  ['Enlightenment', 'Classical liberalism'],
#  ['Conservatism',
#   'Counter-Enlightenment',
#   'Christian humanism',
#   'Clericalism',
#   'Monarchism',
#   'Ultramontanism',
#   'Traditionalism',
#   'Royalism',
#   'Mysticism'],
#  ['Conservatism',
#   'Counter-Enlightenment',
#   'Ultramontanism',
#   'Traditionalism',
#   'Royalism'],
#  ['Continental philosophy', 'French spiritualism'],
#  ['Continental philosophy', 'Post-Marxism', 'Modern Platonism'],
#  ['Stoicism'],
#  ['Continental philosophy',
#   'French historical epistemology',
#   'Conventionalism'],
#  ['Pragmatism', 'functional psychology', 'radical empiricism'],
#  ['French Idealism', 'Critical philosophy', 'French historical epistemology'],
#  ['Liberalism'],
#  ['Continental philosophy', 'French spiritualism', 'philosophy of life'],
#  ['Age of Enlightenment'],
#  ['Post-Kantian', 'Counter-Enlightenment', 'Sturm und Drang'],
#  ['Classical liberalism'],
#  ['Phenomenalism'],
#  ['Post-Kantianism'],
#  ['Logical objectivism', 'Utilitarianism', 'Classical liberalism'],
#  ['Analytic',
#   'Nominalism',
#   'Vienna Circle',
#   'Logical positivism',
#   'Logical atomism',
#   'Logical behaviorism',
#   'Formalism in the philosophy of mathematics'],
#  ['Analytic philosophy'],
#  ['Continental philosophy', 'Critical theory', 'Neopragmatism'],
#  ['German idealism'],
#  ['Neo-Kantianism', 'Existentialism', 'Existential phenomenology'],
#  ['German idealism', 'German skepticism'],
#  ['Analytic philosophy',
#   'Critical rationalism',
#   'Würzburg School',
#   'Metaphysical realism',
#   'Correspondence theory of truth',
#   'Interactionism',
#   'Liberalism'],
#  ['Austrian Enlightenment', 'German idealism'],
#  ['German Idealism',
#   'Jena Romanticism',
#   'Berlin Romanticism',
#   'Romantic hermeneutics',
#   'Methodological hermeneutics'],
#  ['Jena Romanticism',
#   'German idealism',
#   'Epistemic coherentism',
#   'Coherence theory of truth',
#   'Historicism',
#   'Romantic linguistics',
#   'Republicanism',
#   'Conservatism'],
#  ['Neo-Kantianism'],
#  ['School of Brentano',
#   'Aristotelianism',
#   'Intentionalism',
#   'Empirical psychology',
#   'Austrian phenomenology',
#   'Austrian realism'],
#  ['School of Brentano', 'Logical objectivism'],
#  ['German idealism', 'Neo-Kantianism'],
#  ['Neo-Kantianism', 'Marburg school'],
#  ['Neo-Kantianism', 'Baden school'],
#  ['School of Brentano',
#   'Berlin School of experimental psychology',
#   'Phenomenology'],
#  ['Neo-Kantianism', 'Baden School', 'Foundationalism'],
#  ['Continental philosophy',
#   'Post-structuralism',
#   'Deconstruction',
#   'Radical hermeneutics'],
#  ['Phenomenology', 'Material phenomenology'],
#  ['Phenomenology', 'Realist phenomenology', 'Neoplatonism'],
#  ['Continental philosophy', 'Existential phenomenology'],
#  ['Christian existentialism', 'Existential phenomenology', 'Personalism'],
#  ['Phenomenology', 'Postmodernism'],
#  ['Phenomenology',
#   'Existential phenomenology',
#   'Embodied phenomenology',
#   'Western Marxism',
#   'Structuralism',
#   'Post-structuralism'],
#  ['Continental philosophy',
#   'Perspectivism',
#   'Pragmatism',
#   'Vitalism',
#   'Historism',
#   'Existentialism',
#   'Existential phenomenology',
#   'Lebensphilosophie',
#   'philosophy of life',
#   'Neo-Kantianism',
#   'Madrid School',
#   'Liberalism',
#   'Noucentisme'],
#  ['Continental philosophy'],
#  ['Phenomenology', 'Thomism'],
#  ['Analytic',
#   'Neopragmatism',
#   'Postanalytic philosophy',
#   'Mathematical quasi-empiricism',
#   'Metaphysical realism',
#   'Internal realism',
#   'Direct realism',
#   'Transactionalism'],
#  ['Continental philosophy',
#   'Hermeneutic phenomenology',
#   'Psychoanalysis',
#   'Christian theology',
#   'Christian existentialism'],
#  ['Analytic philosophy', 'logical behaviourism'],
#  ['Phenomenology', 'Munich phenomenology', 'Ethical personalism'],
#  ['Analytic',
#   'Pittsburgh School',
#   'Critical realism (philosophy of perception)',
#   'Anti-foundationalism'],
#  ['Continental philosophy', 'Phenomenology', 'Thomism'],
#  ['Continental philosophy', 'Deconstruction', 'Post-structuralism'],
#  ['Pluralist school'],
#  ['Pluralist school'],
#  ['Cynicism'],
#  ['Cyrenaic school'],
#  ['Megarian school'],
#  ['Ionian', 'Milesian', 'naturalism'],
#  ['Ionian', 'Milesian', 'Naturalism'],
#  ['Pre-Socratic'],
#  ['Skepticism'],
#  ['Eleatic school'],
#  ['School of Brentano', 'Graz School', 'Austrian realism'],
#  ['Continental philosophy', 'Marxism'],
#  ['Continental philosophy', 'Goethean science', 'Conservative Revolution'],
#  ['British idealism'],
#  ['Analytic philosophy', 'Logicism', 'Process philosophy', 'Process theology'],
#  ['Neoplatonism'],
#  ['Neoplatonism', 'Alexandrian school'],
#  ['Neoplatonism'],
#  ['Neoplatonism'],
#  ['Neoplatonism'],
#  ['Neoplatonism'],
#  ['Neoplatonism', 'Augustinianism'],
#  ['Renaissance philosophy', 'Aristotelianism'],
#  ['Renaissance humanism', 'Christian humanism'],
#  ['Pythagoreanism'],
#  ['Sophistic movement'],
#  None,
#  ['Persian science',
#   'Islamic science',
#   'Islamic geography',
#   'Islamic mathematics',
#   'Islamic medicine',
#   'Islamic psychological thought'],
#  None,
#  None,
#  None,
#  ['Mercantilism'],
#  ['Continental philosophy', 'Existentialism'],
#  ['Continental philosophy', 'Existentialism'],
#  ['Continental philosophy'],
#  ['Middle Platonism', 'Alexandrian school'],
#  ['Neoplatonism', 'Theological intellectualism'],
#  ['Neoplatonism'],
#  ['Nominalism'],
#  ['Scholasticism'],
#  ['Hussite'],
#  ['Empiricism',
#   'Utilitarianism',
#   'Consequentialism',
#   'Psychologism',
#   'Classical liberalism'],
#  ['Analytic philosophy', 'Consequentialism'],
#  [],
#  ['British idealism'],
#  ['Utilitarianism'],
#  ['Analytic philosophy', 'logical positivism'],
#  ['Analytic',
#   'Mathematical nominalism',
#   'Mathematical quasi-empiricism',
#   'Immanent realism',
#   'Neopragmatism',
#   'Empiricism',
#   'Anti-foundationalism',
#   'Logical behaviorism'],
#  ['Analytic'],
#  ['Analytic philosophy',
#   'Vienna Circle',
#   'Logical positivism',
#   'Foundationalism'],
#  ['Analytic',
#   'Ordinary language philosophy',
#   'linguistic philosophy',
#   'Correspondence theory of truth'],
#  ['Analytic philosophy', 'Berlin Circle'],
#  ['Analytic philosophy'],
#  ['Analytic', 'Historical turn', 'Historiographical externalism'],
#  ['New Atheism', 'Epicureanism'],
#  ['Analytic', 'liberalism'],
#  None,
#  ['Analytic philosophy', 'New Atheism'],
#  ['Scientific skepticism', 'secular humanism'],
#  ['Continental philosophy', 'Postcolonialism'],
#  ['Pragmatism', 'Marxism'],
#  ['Existentialism',
#   'Continental philosophy',
#   'Christian existentialism',
#   'Existential psychology'],
#  ['Age of Enlightenment', 'Rationalism'],
#  ['Age of Enlightenment'],
#  ['Natural law', 'social contract', 'humanism'],
#  ['Continental philosophy',
#   'Hermeneutics',
#   'Epistemological hermeneutics',
#   'Historism',
#   'Lebensphilosophie'],
#  ['Continental philosophy',
#   'Neo-Kantianism',
#   'Realist phenomenology',
#   'Critical realism'],
#  ['Neo-Kantianism'],
#  ['Continental philosophy', 'Philosophy of life'],
#  ['Continental philosophy', 'Phenomenology', 'aesthetic experience'],
#  ['Continental philosophy', 'phenomenology', 'existentialism'],
#  ['Continental philosophy',
#   'Hermeneutics',
#   'Ontological hermeneutics',
#   'Hermeneutic phenomenology'],
#  ['Continental philosophy', 'Lebensphilosophie'],
#  ['Continental philosophy', 'Frankfurt School', 'Western Marxism'],
#  ['Continental philosophy', 'Deconstruction'],
#  ['Transcendental Thomism'],
#  ['Neopragmatism', 'Postanalytic philosophy'],
#  ['Phenomenology', 'philosophical anthropology', 'posthumanism'],
#  ['Continental philosophy',
#   'Anti-foundationalism',
#   'Cosmic nihilism',
#   'Dialectical egoism',
#   'Egoist anarchism',
#   'Nominalism',
#   'Post-Hegelianism',
#   'Young Hegelians'],
#  ['Anarchism', 'Socialism'],
#  ['Anarchism', 'Communism', 'Socialism'],
#  None,
#  ['Neo-Kantianism',
#   'Marburg School',
#   'Phenomenology',
#   'Ontic structural realism'],
#  ['Transcendental Thomism'],
#  ['Thomism', 'Neo-Scholasticism'],
#  ['Gestalt psychology', 'Berlin School of experimental psychology'],
#  ['Process philosophy'],
#  ['Continental philosophy', 'Speculative realism', 'object-oriented ontology'],
#  ['Academic Skepticism'],
#  ['Academic Skepticism'],
#  ['Philosophical skepticism'],
#  ['Empiricism', 'Scottish Enlightenment'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Analytic philosophy', 'Australian realism'],
#  ['Scottish common sense realism',
#   'Scottish Enlightenment',
#   'epistemological externalism',
#   'direct realism',
#   'foundationalism',
#   'correspondence theory of truth'],
#  ['Christian mysticism'],
#  ['Encyclopédistes', 'French materialism', 'Epicurianism'],
#  ['Scottish Common Sense Realism', 'Scottish Enlightenment'],
#  ['Continental philosophy',
#   'Frankfurt School',
#   'critical theory',
#   'Western Marxism'],
#  ['Collectivist anarchism',
#   'Left-Hegelianism',
#   'Left-wing nationalism',
#   'Revolutionary socialism',
#   'Russian materialism',
#   'Westernizers'],
#  ['Rationalism', 'Young Hegelians'],
#  ['German Historical School'],
#  ['British idealism', 'epistemic coherentism'],
#  ['Analytic', 'Pittsburgh School (analytic Hegelianism)', 'Neopragmatism'],
#  ['Continental philosophy',
#   'Existentialism',
#   'Existential phenomenology',
#   'French feminism',
#   'Western Marxism'],
#  ['Continental philosophy',
#   'third-wave feminism',
#   'critical theory',
#   'queer theory',
#   'postmodernism',
#   'post-structuralism',
#   'performative turn'],
#  ['British idealism', 'Historism'],
#  ['Continental philosophy', 'Eclectic', 'spiritualism'],
#  ['Neo-Hegelianism', 'Classical liberalism', 'Historism'],
#  ['Anthropological materialism', 'Secular humanism', 'Young Hegelians'],
#  ['Hegelianism', 'Neo-Kantianism'],
#  ['Neo-Hegelianism'],
#  ['British idealism', 'social liberalism'],
#  ['Continental philosophy'],
#  ['Continental philosophy'],
#  ['Neo-Hegelianism', 'Existential phenomenology', 'Marxism'],
#  ['Neo-Kantianism', 'Western Marxism', 'Hegelian Marxism'],
#  ['Analytic philosophy',
#   'Pittsburgh School',
#   'Foundationalism',
#   'Perceptual conceptualism',
#   'Direct realism'],
#  ['Continental', 'Hegelianism'],
#  ['Neo-Hegelianism', 'Analytic school', 'Social philosophy'],
#  ['Analytic philosophy', 'Utilitarianism'],
#  None,
#  ['Continental philosophy',
#   'Ljubljana school of psychoanalysis',
#   'Lacanian psychoanalysis',
#   'Post-Hegelianism',
#   'Freudo-Marxism'],
#  ['Classical liberalism'],
#  ['History of art', 'Cultural history'],
#  ['Continental philosophy',
#   'Post-Kantian philosophy',
#   'Metaphysical voluntarism',
#   'Post-Schopenhauerian pessimism',
#   'Pluralism'],
#  ['Continental philosophy',
#   'Metaphysical voluntarism',
#   'Post-Schopenhauerian pessimism',
#   'Pluralism',
#   'Transcendental realism'],
#  ['Continental philosophy',
#   'Post-phenomenology',
#   'Western Marxism',
#   'post-Marxism',
#   'Libertarian socialism',
#   'Revolutionary socialism',
#   'Classical republicanism',
#   'Philosophy of praxis',
#   'Post-Lacanian psychoanalysis'],
#  ['Continental philosophy',
#   'Philosophical pessimism',
#   'Existentialism',
#   'Irrationalism'],
#  None,
#  ['Analytic philosophy',
#   'Aristotelianism',
#   'aretaic turn',
#   'Thomism',
#   'communitarianism'],
#  ['Christian existentialism'],
#  ['Monism', 'Holism in science', 'Goethean science', 'Anthroposophy'],
#  ['Radical pragmatism'],
#  ['Stoicism'],
#  ['Stoicism'],
#  ['Stoicism'],
#  ['Stoicism'],
#  ['Aristotelianism',
#   'Epicureanism',
#   'Atomism',
#   'Empiricism',
#   'Nominalism',
#   'Materialism',
#   'Corpuscularianism',
#   'Theological voluntarism'],
#  ['Saint-Simonianism', 'Socialism', 'Utopian socialism'],
#  ['Utopian socialism', 'Fourierism'],
#  ['French materialism'],
#  ['Utilitarianism', 'French materialism'],
#  ['Psychoanalysis', 'Structuralism', 'Post-structuralism'],
#  ['Continental philosophy',
#   'Structuralism',
#   'Semiotics',
#   'Post-structuralism'],
#  ['Transcendentalism'],
#  None,
#  ['Utilitarianism', 'Legal positivism', 'Liberalism', 'Epicureanism'],
#  ['Philosophical anarchism', 'Utilitarianism'],
#  ['Westernizers', 'Agrarian', 'populism'],
#  ['Liberalism', 'Republicanism', 'Secular humanism'],
#  ['Libertine'],
#  ['Continental philosophy', 'Platonism'],
#  ['Pragmatism', 'Instrumentalism'],
#  ['Analytic', 'Social liberalism'],
#  ['Continental philosophy',
#   'French rationalism',
#   'French historical epistemology'],
#  ['Continental philosophy', 'Western Marxism', 'Hegelian', 'Marxism'],
#  ['Continental philosophy', 'French liberalism'],
#  ['Marxism', 'Black existentialism', 'Critical theory'],
#  ['Continental philosophy', 'Structural Marxism'],
#  ['Structuralism', 'Genetic structuralism', 'Critical sociology'],
#  ['Analytic philosophy', 'Instrumentalism'],
#  ['Continental philosophy', 'French Nietzscheanism'],
#  ['Continental philosophy',
#   'French rationalism',
#   'French historical epistemology',
#   'Anti-positivism'],
#  ['Continental philosophy', 'psychoanalysis', 'post-structuralism'],
#  ['Conservatism'],
#  ['Christian humanism', 'Renaissance humanism'],
#  ['Molinism', 'School of Salamanca'],
#  ['Aristotelianism', 'Augustinianism', 'Empiricism', 'Christian humanism'],
#  ['Continental philosophy', 'Western Marxism', 'Marxist hermeneutics'],
#  [],
#  ['Continental philosophy',
#   'Western Marxism',
#   'Libertarian socialism',
#   'Anti-totalitarian',
#   'left'],
#  ['Continental philosophy'],
#  ['Continental philosophy', 'Existentialism'],
#  ['Continental philosophy', 'Speculative realism', 'transcendental nihilism'],
#  ['Continental philosophy',
#   'Accelerationism',
#   'Speculative realism',
#   'Dark Enlightenment'],
#  None,
#  ['Atomism', 'Materialism'],
#  ['Epicureanism'],
#  ['Continental philosophy',
#   'Western Marxism',
#   'neo-Marxism',
#   'Marxist humanism'],
#  ['Neorealism'],
#  ['Continental philosophy',
#   'Conservative Revolution',
#   'Decisionism',
#   'IR realism'],
#  ['Civic republicanism'],
#  ['German idealism', 'Krausism', 'Panentheism'],
#  ['German idealism', 'German skepticism'],
#  ['Continental philosophy',
#   'Post-Kantian philosophy',
#   'Transcendental realism',
#   'Metaphysical voluntarism',
#   'Post-Schopenhauerian pessimism',
#   'Pantheism',
#   'Irrationalism'],
#  ['Continental philosophy',
#   'Frankfurt School',
#   'critical theory',
#   'Western Marxism'],
#  None,
#  ['Christian mysticism', 'Russian symbolism', 'Russian Schellingianism'],
#  ['Neo-Kantianism', 'Fictionalism'],
#  ['Idealism', 'Kantian ethics'],
#  ['Continental philosophy', 'Biosophy', 'Philosophical pessimism'],
#  ['German idealism', 'Speculative theism'],
#  ['Continental philosophy',
#   'Speculative realism',
#   'transcendental materialism'],
#  ['Continental philosophy', 'French spiritualism'],
#  ['Objective idealism', 'American idealism'],
#  ['Calvinism',
#   'presuppositionalism',
#   'Christian philosophy',
#   'new hermeneutic'],
#  ['Perennial philosophy'],
#  ['German idealism', 'Speculative theism'],
#  ['Analytic', 'Nominalism'],
#  ['Analytic philosophy', 'Vienna Circle'],
#  ['Analytic'],
#  ['German idealism'],
#  ['Conceptual pragmatism', 'Analytic philosophy', 'Epistemic coherentism'],
#  ['German idealism', 'Post-Kantianism'],
#  ['Continental philosophy'],
#  ['German idealism', 'Naturphilosophie', 'Non-philosophy'],
#  ['Berlin Romanticism', 'Romantic linguistics', 'Classical liberalism'],
#  None,
#  ['Analytic philosophy'],
#  ['Analytical Thomism'],
#  ['Analytic'],
#  ['Analytic', 'Neo-logicism', 'Scottish School'],
#  ['Analytic philosophy', 'Epistemological anarchism'],
#  ['Analytic philosophy'],
#  None,
#  ['Continental philosophy', 'French historical epistemology'],
#  ['Continental philosophy', 'Western Marxism', 'Structural Marxism'],
#  ['Continental philosophy',
#   'Western Marxism',
#   'post-Marxism',
#   'post-structuralism',
#   'postmodernism'],
#  ['Neo-Kantianism', 'Marburg School'],
#  None,
#  ['British idealism', 'Liberal conservatism'],
#  ['Continental philosophy', 'Kabbalah', 'Wissenschaft des Judentums'],
#  ['Continental'],
#  [],
#  ['Analytic philosophy', 'Aristotelianism', 'feminism', 'social liberalism'],
#  ['German idealism'],
#  ['Continental philosophy'],
#  ['Confucianism'],
#  ['Confucianism', 'Neo-Confucianism'],
#  ['Physiocrats'],
#  ['Neo-Kantianism', 'Baden school'],
#  ['German idealism', 'Aristotelianism', 'Aristotelian', 'idealism'],
#  ['Analytic philosophy', 'Berlin Circle', 'Logical behaviorism'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Renaissance humanism'],
#  ['Classical economics'],
#  None,
#  ['Republicanism'],
#  ['Cambridge Platonists'],
#  ['Perennialism', 'Traditionalism', 'Italian Fascism'],
#  ['Toronto School of communication theory'],
#  ['German idealism', 'Western Marxism'],
#  ['Continental philosophy', 'Sorelianism', 'Marxism', 'Socialism'],
#  None,
#  ['Traditionalist conservatism'],
#  ['Maurrassisme',
#   'Positivism',
#   'Royalism',
#   'Integral Nationalism',
#   'reactionary',
#   'Action Française'],
#  None,
#  ['French spiritualism'],
#  ['Christian existentialism', 'personalism'],
#  ['Continental philosophy', 'Philosophy of life'],
#  ['Continental philosophy', 'Non-philosophy'],
#  ['Continental philosophy', 'Speculative realism', 'speculative materialism'],
#  ['Cynicism'],
#  ['Individualist anarchism'],
#  ['empiricism', 'determinism'],
#  ['pragmatism'],
#  None,
#  ['Continental philosophy', 'Phenomenology', 'French historical epistemology'],
#  None,
#  ['Continental philosophy',
#   'Western Marxism',
#   'Ultra-left',
#   'Letterist International',
#   'Situationist'],
#  ['Continental philosophy'],
#  ['Sunni Islam', 'Sufism'],
#  ['Existential Thomism'],
#  ['Continental philosophy', 'Personalism', 'Non-conformists of the 1930s'],
#  ['Cameralism'],
#  ['Physiocracy'],
#  ['Classical economics'],
#  ['Georgism'],
#  ['Analytic', 'Berlin Circle', 'Logical empiricism'],
#  ['Analytic philosophy',
#   'Historical turn',
#   'Fallibilism',
#   'Falsificationism',
#   'Mathematical quasi-empiricism',
#   'Historiographical internalism'],
#  ['Analytic', 'Nominalism', 'Perdurantism'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy',
#   'Vienna Circle',
#   'Logical positivism',
#   'Metaphysical realism'],
#  ['Postanalytic philosophy'],
#  ['Pragmatism'],
#  ['Critical theory', 'Pragmatism'],
#  ['Continental philosophy', 'Frankfurt School'],
#  ['Post-Kantianism'],
#  ['Existentialism', 'Phenomenology'],
#  ['Analytic philosophy', 'Critical rationalism'],
#  ['Analytic', 'Scientific structuralism'],
#  ['Analytic'],
#  ['Continental philosophy'],
#  ['Romantic linguistics'],
#  ['School of Brentano'],
#  ['School of Brentano', 'Graz School', 'Gestalt psychology'],
#  ['Western Marxism', 'Marxist hermeneutics'],
#  ['Neo-Kantianism',
#   'Baden school',
#   'History of religions school',
#   'Liberal Christianity',
#   'Classical liberalism'],
#  ['Structuralism', 'linguistic turn', 'semiotics'],
#  ['Structuralism'],
#  ['Continental philosophy',
#   'deconstructionism',
#   'phenomenology',
#   'postmodern Christianity'],
#  ['Continental philosophy',
#   'Postmodern philosophy',
#   'Postmodern Christianity',
#   'Post-structuralist',
#   'psychoanalysis',
#   'Phenomenology',
#   'Existentialism',
#   'Apophatic theology',
#   'Death of God theology'],
#  ['Continental philosophy', 'Western Marxism'],
#  ['Christian philosophy', 'French idealism'],
#  ['Analytic'],
#  ['Continental philosophy', 'Hermeneutic phenomenology'],
#  ['Continental philosophy', 'French feminism'],
#  None,
#  None,
#  ['Nouvelle Droite'],
#  ['Thomism', 'Christian philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic', 'Scientific realism', 'Moral realism'],
#  ['Analytic philosophy'],
#  ['Moscow linguistic circle', 'Prague linguistic circle'],
#  ['British idealism'],
#  ['Analytic'],
#  ['Analytic philosophy', 'Australian realism', 'Logical behaviorism'],
#  ['Analytical Marxism', 'left-libertarianism', 'egalitarianism'],
#  ['Analytic'],
#  ['Analytic philosophy', 'Australian realism'],
#  ['Continental philosophy', 'German idealism'],
#  ['Munich phenomenology'],
#  ['Neo-Kantianism', 'Lebensphilosophie'],
#  ['Continental philosophy',
#   'Phenomenology',
#   'Munich phenomenology',
#   'Personalism'],
#  ['Sophistic movement'],
#  ['Cynicism'],
#  ['Cyrenaic school'],
#  ['Megarian school'],
#  ['Graz School',
#   'object theory',
#   'Austrian realist',
#   "Meinong's School",
#   'Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy', 'Noneism', 'Environmental philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Process philosophy'],
#  ['Realism', 'Platonism', 'Neoplatonism', 'Aristotelianism', 'Traditionalism'],
#  ['Analytic philosophy'],
#  ['Neoplatonism'],
#  None,
#  ['Renaissance humanism'],
#  ['Renaissance philosophy', 'Christian humanism', 'Neoplatonism'],
#  None,
#  None,
#  ['Ijtihad'],
#  ['Twelver Shia'],
#  ['Perennialism', 'Sufism'],
#  ['Taoism', 'Philosophical skepticism'],
#  None,
#  ['Associationalism', 'Utilitarianism', 'Liberalism', 'Ricardian economics'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Analytic'],
#  ['Analytic philosophy', 'Logical positivism'],
#  ['Analytic philosophy', 'Ethical intuitionism'],
#  ['Direct realism'],
#  ['Analytic philosophy', 'Scientific realism'],
#  ['pragmatism'],
#  ['Analytic', 'Neopragmatism', 'Foundherentism'],
#  ['French historical epistemology',
#   'Epistemological realism',
#   'Neo-Kantianism'],
#  ['Analytic philosophy'],
#  ['British historiography'],
#  ['Analytic philosophy', 'Pragmatism'],
#  ['New Atheism'],
#  ['Analytic'],
#  ['Anarchism', 'Continental philosophy', 'Non-conformists of the 1930s'],
#  ['Historism'],
#  ['Continental philosophy', 'Western Marxism', 'Genetic epistemology'],
#  ['Catholicism'],
#  ['Continental philosophy',
#   'Anti-foundationalism',
#   'Anti-militarism',
#   'Biocentrism',
#   'Lebensphilosophie',
#   'Perspectivism'],
#  ['Continental philosophy',
#   'Marxism',
#   'Christian anarchism',
#   'Christian socialism',
#   'Christian Mysticism',
#   'Individualism',
#   'Modern Platonism'],
#  ['Continental philosophy', 'Phenomenology', 'Hermeneutics'],
#  ['Anarchism', 'Green anarchism', 'Left-libertarianism'],
#  ['Post-left anarchy'],
#  None,
#  ['Anarchism', 'Mutualism', 'Socialism'],
#  ['Individualist anarchism'],
#  ['Individualist anarchism', 'Egoist anarchism', 'Futurism', 'Existentialism'],
#  ['Anarchism', 'Feminism'],
#  None,
#  ['Austromarxism'],
#  ['Anarcho-communism'],
#  ['non-denominational Evangelical Christian',
#   'Amyraldism',
#   'Neo-Thomistic Philosophy',
#   'Premillennial-Dispensational'],
#  ['School of Illumination'],
#  ['Peripatetic school'],
#  ['Academic skepticism', 'Platonism'],
#  ['Enlightenment', 'Classical liberalism', 'Economic liberalism'],
#  ['Empiricism', 'Christian philosophy'],
#  ['Analytic philosophy', 'Australian realism', 'Libertarianism'],
#  ['Analytic', 'Libertarianism'],
#  ['Empiricism'],
#  ['Western Marxism', 'Marxist hermeneutics'],
#  ['Anarcho-communism', 'Collectivist anarchism', 'Marxism'],
#  ['Western Marxism'],
#  ['Orthodox Marxism'],
#  ['German Historical School'],
#  ['British idealism'],
#  ['Marxism'],
#  ['Italian nationalism', 'Romanticism'],
#  ['British idealism', 'analytic philosophy'],
#  ['Continental Philosophy'],
#  ['Continental philosophy', 'Marxist humanism'],
#  ['Analytic philosophy', 'Aretaic turn', 'Aristotelianism'],
#  ['Analytic'],
#  None,
#  ['Analytic philosophy', 'Virtue ethics', 'Modern Platonism'],
#  ['Analytic', 'communitarianism'],
#  ['Analytic', 'communitarianism', 'socialism'],
#  ['Post-Marxism'],
#  ['Ljubljana school of psychoanalysis'],
#  None,
#  None,
#  None,
#  ['Theosophy'],
#  ['Jungian psychology', 'Participatory theory', 'Transpersonal psychology'],
#  ['Stoicism'],
#  ['Stoicism'],
#  None,
#  ['Post-anarchism', 'individualist anarchism'],
#  ['Russian nihilism', 'Utopian socialism', 'Narodism'],
#  ['Empiricism'],
#  ['Marxism', 'Dialectical materialism', 'Historical materialism'],
#  ['Anarcho-primitivism', 'post-left anarchy'],
#  None,
#  None,
#  ['Legal positivism'],
#  ['Analytic', 'Legal positivism'],
#  ['Analytic', 'Legal interpretivism'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Analytic philosophy'],
#  ['Continental philosophy', 'French epistemology'],
#  ['Continental philosophy', 'Western Marxism', 'phenomenology'],
#  None,
#  ['Postcolonialism'],
#  ['Analytic'],
#  ['Advaita Vedanta', 'Sufism', 'Nondualism', 'Platonism', 'Traditionalism'],
#  ['Epicureanism'],
#  ['Marxism'],
#  ['Neorealism'],
#  ['Continental philosophy', 'Immanent philosophy', 'Greifswald objectivism'],
#  ['Continental philosophy',
#   'Frankfurt School',
#   'psychoanalysis',
#   'Marxist humanism',
#   'humanistic Judaism'],
#  ['Classicism', 'Enlightenment', 'Romanticism'],
#  ['Christian mysticism', 'Christian philosophy'],
#  ['Legal positivism'],
#  ['German idealism', 'Speculative theism', 'Spiritism'],
#  ['Aristotelian', 'idealism'],
#  ['rationalism',
#   'American idealism',
#   'Epistemological idealism',
#   'Epistemic coherentism',
#   'Coherence theory of truth'],
#  ['Presuppositionalism', 'Christian Philosophy'],
#  ['Analytic'],
#  ['Analytic'],
#  None,
#  ['Process philosophy'],
#  ['Historicism'],
#  ['Analytic philosophy'],
#  ['Analytic'],
#  ['Analytic philosophy'],
#  ['German Romanticism'],
#  ['Analytic philosophy'],
#  ['Neo-Kantianism'],
#  ['Neo-Confucianism'],
#  None,
#  ['Analytic'],
#  ['Analytic', 'Libertarianism'],
#  ['Analytic'],
#  ['French spiritualism'],
#  ['Zen', 'perennialism'],
#  ['Aristotelianism', 'Thomism'],
#  ['pragmatism'],
#  ['Analytic'],
#  ['Pragmatism', 'Pragmatic naturalism', 'Young Radicals'],
#  ["Ba'athism", 'Arab nationalism'],
#  None,
#  ['Islamic philosophy'],
#  ['Sunni Islam'],
#  None,
#  ['Analytic philosophy'],
#  ['Analytic Philosophy', 'Ethics', 'Philosophy of language', 'Feminism'],
#  None,
#  ['Neo-Friesian'],
#  ['Continental philosophy', 'Phenomenology'],
#  None,
#  ['Neogrammarian'],
#  None,
#  ['Marxism', 'nationalism'],
#  ['German idealism', 'Russian personalism'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  None,
#  None,
#  ['Analytic philosophy'],
#  ['Renaissance humanism'],
#  ['Thomism'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Perennial philosophy'],
#  ['Analytic'],
#  ['Analytic philosophy'],
#  ['Analytic philosophy'],
#  ['Critical realism (philosophy of the social sciences)'],
#  None,
#  ['Individualist anarchism', 'Mutualism'],
#  None,
#  ['Nietzscheanism', 'existentialism'],
#  ['Fourth Way'],
#  ['Peripateticism'],
#  ['British idealism'],
#  ['Analytic philosophy', 'Australian realism'],
#  ['Western Marxism'],
#  [],
#  ['Ljubljana school of psychoanalysis',
#   'Continental philosophy',
#   'Lacanian psychoanalysis',
#   'Post-Hegelianism'],
#  ['Sunni', 'Naqshbandi', 'Madariya'],
#  None,
#  None,
#  None,
#  ['Socialism'],
#  ['Socialism'],
#  ['Russian nihilism'],
#  None,
#  ['Legal positivism', 'Perfectionist liberalism'],
#  ['Liberal socialism'],
#  ['Analytic'],
#  ['Socialism'],
#  ['Libertarianism', 'Arizona School liberalism'],
#  ['Analytic', 'Scientific structuralism', 'Stanford School'],
#  ['Neopragmatism'],
#  ['Modernism', 'Classical', 'Arabic literature', 'Nahda'],
#  ['Continental philosophy'],
#  None,
#  ['Structuralism'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['British idealism'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Secular humanism'],
#  ['Zahiri'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Speculative idealism'],
#  None,
#  None,
#  None,
#  ['Romanticism', 'Serb epic poetry'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Maliki'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Marxism', 'Đilasism'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Hanafi'],
#  ['Zahiri'],
#  None,
#  ['Hanbali'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Hanbali'],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
